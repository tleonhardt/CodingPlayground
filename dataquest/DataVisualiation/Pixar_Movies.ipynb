# %% [markdown]
# [Pixar Animation](https://en.wikipedia.org/wiki/Pixar) is one of the most well known animation studios in the world and many people worldwide religiously watch every new released film.
#
# Here we use a dataset on Pixar movies gathered from multiple sources including:
# * Box Office Mojo
# * IMDB
# * Rotten Tomatoes
# * Metacritic
#
# Here are some of the columns in our dataset **PixarMovies.csv**:
# * Year Released - the year the movie was released.
# * Movie - the name of the movie.
# * RT Score - the Rotten Tomatoes rating for the movie.
# * IMDB Score - the IMDB rating for the movie.
# * Metacritic SCore - the Metacritic rating for the movie.
# * Opening Weekend - the amount of revenue the movie made on opening weekend (in millions of dollars).
# * Worldwide Gross - the total amount of revenue the movie has made to date.
# * Production Budget - the amount of money spent to produce the film (in millions of dollars).
# * Oscars Won - the number of Oscar awards the movie won.

# %%
# Setup the environment by importing the libraries we need
import pandas as pd
import matplotlib.pyplot as plt
# Note: Importing seaborn effects all matplotlib and pandas plots as well
import seaborn as sns

# Run the Jupyter magic so that plots are displayed in the notebook
# %matplotlib notebook

# %%
# Read the dataset into a DataFrame and determine the dimensions
pixar_movies = pd.read_csv('../data/PixarMovies.csv')
pixar_movies.shape
# Out:
# (15, 16)

# %%
# Display the entire dataset since it isn't too big
pixar_movies.head(15)
# Out:
#     Year Released                Movie  Length  RT Score  IMDB Score  \
# 0            1995            Toy Story      81       100         8.3
# 1            1998         A Bug's Life      96        92         7.2
# 2            1999          Toy Story 2      92       100         7.9
# 3            2001       Monsters, Inc.      90        96         8.1
# 4            2003         Finding Nemo     104        99         8.2
# 5            2004      The Incredibles     115        97         8.0
# 6            2006                 Cars     116        74         7.2
# 7            2007          Ratatouille     111        96         8.0
# 8            2008               WALL-E      97        96         8.4
# 9            2009                   Up      96        98         8.3
# 10           2010          Toy Story 3     103        99         8.4
# 11           2011               Cars 2     113        39         6.3
# 12           2012                Brave     100        78         7.2
# 13           2013  Monsters University     107        78         7.4
# 14           2015           Inside Out     102        98         8.8
#
#     Metacritic Score  Opening Weekend  Worldwide Gross  Domestic Gross  \
# 0                 92            29.14            362.0           191.8
# 1                 77            33.26            363.4           162.8
# 2                 88            57.39            485.0           245.9
# 3                 78            62.58            528.8           255.9
# 4                 90            70.25            895.6           339.7
# 5                 90            70.47            631.4           261.4
# 6                 73            60.12            462.0           244.1
# 7                 96            47.00            623.7           206.4
# 8                 94            63.10            521.3           223.8
# 9                 88            68.11            731.3           293.0
# 10                92           110.31           1063.2           415.0
# 11                57           109.00            559.9           191.5
# 12                69            66.30            539.0           237.3
# 13                65            82.43            743.6           268.5
# 14                93            90.40            677.1           340.5
#
#     Adjusted Domestic Gross  International Gross Domestic % International %  \
# 0                    356.21                170.2     52.98%          47.02%
# 1                    277.18                200.6     44.80%          55.20%
# 2                    388.43                239.2     50.70%          49.32%
# 3                    366.12                272.9     48.39%          51.61%
# 4                    457.46                555.9     37.93%          62.07%
# 5                    341.28                370.0     41.40%          58.60%
# 6                    302.59                217.9     52.84%          47.16%
# 7                    243.65                417.3     33.09%          66.91%
# 8                    253.11                297.5     42.93%          57.07%
# 9                    318.90                438.3     40.07%          59.93%
# 10                   423.88                648.2     39.03%          60.97%
# 11                   194.43                368.4     34.20%          65.80%
# 12                   243.39                301.7     44.03%          55.97%
# 13                   269.59                475.1     36.11%          63.89%
# 14                   340.50                336.6     50.29%          49.71%
#
#     Production Budget  Oscars Nominated  Oscars Won
# 0                  30               3.0         0.0
# 1                  45               1.0         0.0
# 2                  90               1.0         0.0
# 3                 115               3.0         1.0
# 4                  94               4.0         1.0
# 5                  92               4.0         2.0
# 6                  70               2.0         0.0
# 7                 150               5.0         1.0
# 8                 180               6.0         1.0
# 9                 175               5.0         2.0
# 10                200               5.0         2.0
# 11                200               0.0         0.0
# 12                185               1.0         1.0
# 13                200               0.0         0.0
# 14                175               NaN         NaN

# %%
# Get the datatypes for each column
pixar_movies.dtypes
# Out:
# Year Released                int64
# Movie                       object
# Length                       int64
# RT Score                     int64
# IMDB Score                 float64
# Metacritic Score             int64
# Opening Weekend            float64
# Worldwide Gross            float64
# Domestic Gross             float64
# Adjusted Domestic Gross    float64
# International Gross        float64
# Domestic %                  object
# International %             object
# Production Budget            int64
# Oscars Nominated           float64
# Oscars Won                 float64
# dtype: object

# %%
# Generate some summary statistics
pixar_movies.describe()
# Out:
#        Year Released      Length    RT Score  IMDB Score  Metacritic Score  \
# count      15.000000   15.000000   15.000000   15.000000         15.000000
# mean     2006.066667  101.533333   89.333333    7.846667         82.800000
# std         5.933761    9.927355   16.451950    0.655599         12.119642
# min      1995.000000   81.000000   39.000000    6.300000         57.000000
# 25%      2002.000000   96.000000   85.000000    7.300000         75.000000
# 50%      2007.000000  102.000000   96.000000    8.000000         88.000000
# 75%      2010.500000  109.000000   98.500000    8.300000         92.000000
# max      2015.000000  116.000000  100.000000    8.800000         96.000000
#
#        Opening Weekend  Worldwide Gross  Domestic Gross  \
# count        15.000000        15.000000       15.000000
# mean         67.990667       612.486667      258.506667
# std          23.270468       190.193934       66.518284
# min          29.140000       362.000000      162.800000
# 25%          58.755000       503.150000      215.100000
# 50%          66.300000       559.900000      245.900000
# 75%          76.450000       704.200000      280.750000
# max         110.310000      1063.200000      415.000000
#
#        Adjusted Domestic Gross  International Gross  Production Budget  \
# count                15.000000            15.000000          15.000000
# mean                318.448000           353.986667         133.400000
# std                  73.321064           135.061615          59.696614
# min                 194.430000           170.200000          30.000000
# 25%                 261.350000           256.050000          91.000000
# 50%                 318.900000           336.600000         150.000000
# 75%                 361.165000           427.800000         182.500000
# max                 457.460000           648.200000         200.000000
#
#        Oscars Nominated  Oscars Won
# count         14.000000   14.000000
# mean           2.857143    0.785714
# std            2.032700    0.801784
# min            0.000000    0.000000
# 25%            1.000000    0.000000
# 50%            3.000000    1.000000
# 75%            4.750000    1.000000
# max            6.000000    2.000000

# %%
# Strip the percentage sign (%) from the end of values and convert to float
pixar_movies['Domestic %'] = pixar_movies['Domestic %'].str.rstrip('%').astype(float)
pixar_movies['International %'] = pixar_movies['International %'].str.rstrip('%').astype(float)
pixar_movies[['Domestic %', 'International %']].head()
# Out:
#    Domestic %  International %
# 0       52.98            47.02
# 1       44.80            55.20
# 2       50.70            49.32
# 3       48.39            51.61
# 4       37.93            62.07

# %%
# Multiply IMDB Scroe column by 10 to convert to a 100 point scale
pixar_movies['IMDB Score'] = pixar_movies['IMDB Score'] * 10
pixar_movies.head()
# Out:
#    Year Released           Movie  Length  RT Score  IMDB Score  \
# 0           1995       Toy Story      81       100        83.0
# 1           1998    A Bug's Life      96        92        72.0
# 2           1999     Toy Story 2      92       100        79.0
# 3           2001  Monsters, Inc.      90        96        81.0
# 4           2003    Finding Nemo     104        99        82.0
#
#    Metacritic Score  Opening Weekend  Worldwide Gross  Domestic Gross  \
# 0                92            29.14            362.0           191.8
# 1                77            33.26            363.4           162.8
# 2                88            57.39            485.0           245.9
# 3                78            62.58            528.8           255.9
# 4                90            70.25            895.6           339.7
#
#    Adjusted Domestic Gross  International Gross  Domestic %  International %  \
# 0                   356.21                170.2       52.98            47.02
# 1                   277.18                200.6       44.80            55.20
# 2                   388.43                239.2       50.70            49.32
# 3                   366.12                272.9       48.39            51.61
# 4                   457.46                555.9       37.93            62.07
#
#    Production Budget  Oscars Nominated  Oscars Won
# 0                 30               3.0         0.0
# 1                 45               1.0         0.0
# 2                 90               1.0         0.0
# 3                115               3.0         1.0
# 4                 94               4.0         1.0

# %%
# Create a new DataFrame with the last row filtered out
filtered_pixar = pixar_movies.dropna()
filtered_pixar
# Out:
#     Year Released                Movie  Length  RT Score  IMDB Score  \
# 0            1995            Toy Story      81       100        83.0
# 1            1998         A Bug's Life      96        92        72.0
# 2            1999          Toy Story 2      92       100        79.0
# 3            2001       Monsters, Inc.      90        96        81.0
# 4            2003         Finding Nemo     104        99        82.0
# 5            2004      The Incredibles     115        97        80.0
# 6            2006                 Cars     116        74        72.0
# 7            2007          Ratatouille     111        96        80.0
# 8            2008               WALL-E      97        96        84.0
# 9            2009                   Up      96        98        83.0
# 10           2010          Toy Story 3     103        99        84.0
# 11           2011               Cars 2     113        39        63.0
# 12           2012                Brave     100        78        72.0
# 13           2013  Monsters University     107        78        74.0
#
#     Metacritic Score  Opening Weekend  Worldwide Gross  Domestic Gross  \
# 0                 92            29.14            362.0           191.8
# 1                 77            33.26            363.4           162.8
# 2                 88            57.39            485.0           245.9
# 3                 78            62.58            528.8           255.9
# 4                 90            70.25            895.6           339.7
# 5                 90            70.47            631.4           261.4
# 6                 73            60.12            462.0           244.1
# 7                 96            47.00            623.7           206.4
# 8                 94            63.10            521.3           223.8
# 9                 88            68.11            731.3           293.0
# 10                92           110.31           1063.2           415.0
# 11                57           109.00            559.9           191.5
# 12                69            66.30            539.0           237.3
# 13                65            82.43            743.6           268.5
#
#     Adjusted Domestic Gross  International Gross  Domestic %  International %  \
# 0                    356.21                170.2       52.98            47.02
# 1                    277.18                200.6       44.80            55.20
# 2                    388.43                239.2       50.70            49.32
# 3                    366.12                272.9       48.39            51.61
# 4                    457.46                555.9       37.93            62.07
# 5                    341.28                370.0       41.40            58.60
# 6                    302.59                217.9       52.84            47.16
# 7                    243.65                417.3       33.09            66.91
# 8                    253.11                297.5       42.93            57.07
# 9                    318.90                438.3       40.07            59.93
# 10                   423.88                648.2       39.03            60.97
# 11                   194.43                368.4       34.20            65.80
# 12                   243.39                301.7       44.03            55.97
# 13                   269.59                475.1       36.11            63.89
#
#     Production Budget  Oscars Nominated  Oscars Won
# 0                  30               3.0         0.0
# 1                  45               1.0         0.0
# 2                  90               1.0         0.0
# 3                 115               3.0         1.0
# 4                  94               4.0         1.0
# 5                  92               4.0         2.0
# 6                  70               2.0         0.0
# 7                 150               5.0         1.0
# 8                 180               6.0         1.0
# 9                 175               5.0         2.0
# 10                200               5.0         2.0
# 11                200               0.0         0.0
# 12                185               1.0         1.0
# 13                200               0.0         0.0

# %%
# Set the Movie column as the index for both DataFrames
pixar_movies.set_index('Movie', inplace=True)
filtered_pixar.set_index('Movie', inplace=True)
pixar_movies.head()
# Out:
#                 Year Released  Length  RT Score  IMDB Score  Metacritic Score  \
# Movie
# Toy Story                1995      81       100        83.0                92
# A Bug's Life             1998      96        92        72.0                77
# Toy Story 2              1999      92       100        79.0                88
# Monsters, Inc.           2001      90        96        81.0                78
# Finding Nemo             2003     104        99        82.0                90
#
#                 Opening Weekend  Worldwide Gross  Domestic Gross  \
# Movie
# Toy Story                 29.14            362.0           191.8
# A Bug's Life              33.26            363.4           162.8
# Toy Story 2               57.39            485.0           245.9
# Monsters, Inc.            62.58            528.8           255.9
# Finding Nemo              70.25            895.6           339.7
#
#                 Adjusted Domestic Gross  International Gross  Domestic %  \
# Movie
# Toy Story                        356.21                170.2       52.98
# A Bug's Life                     277.18                200.6       44.80
# Toy Story 2                      388.43                239.2       50.70
# Monsters, Inc.                   366.12                272.9       48.39
# Finding Nemo                     457.46                555.9       37.93
#
#                 International %  Production Budget  Oscars Nominated  \
# Movie
# Toy Story                 47.02                 30               3.0
# A Bug's Life              55.20                 45               1.0
# Toy Story 2               49.32                 90               1.0
# Monsters, Inc.            51.61                115               3.0
# Finding Nemo              62.07                 94               4.0
#
#                 Oscars Won
# Movie
# Toy Story              0.0
# A Bug's Life           0.0
# Toy Story 2            0.0
# Monsters, Inc.         1.0
# Finding Nemo           1.0

# %%
# Create a new DataFrame containing just the critics reviews
critics_reviews = pixar_movies[['RT Score', 'IMDB Score', 'Metacritic Score']]
critics_reviews.head()
# Out:
#                 RT Score  IMDB Score  Metacritic Score
# Movie
# Toy Story            100        83.0                92
# A Bug's Life          92        72.0                77
# Toy Story 2          100        79.0                88
# Monsters, Inc.        96        81.0                78
# Finding Nemo          99        82.0                90

# %%
# Use the DataFrame plot() metod to visualize this new DataFrame
critics_reviews.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
# The resulting plot is a little cramped, so lets tweak the figure size
critics_reviews.plot(figsize=(9,6))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Note: Note all movie names are listed on the x-axis and the vertical grid line on the x-aixs exist only for every other movie.

# %%
# Box plot
critics_reviews.plot(kind='box', figsize=(9,5))
# Out:
# <img src="data:image/png;base64,...">

# %%
# Stacked bar plot
revenue_proportions = filtered_pixar[['Domestic %', 'International %']]
revenue_proportions.plot(kind='bar', stacked='True', figsize=(9,6))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Create a grouped bar plot to explore if there's any correlation between the number of Oscars a movie was nominated for and the number it actually won.

# %%
# Create a grouped bar plot
movie_oscars = filtered_pixar[['Oscars Nominated', 'Oscars Won']]
movie_oscars.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# What plots can you generate to better understand which columns correlate with the Adjusted Domestic Gross revenue column, which describes the total domestic revenue adjusted for economic and ticket price inflation?

# %%
# Generate plots to better understand which columsn correlate with the Adjusted Domestic Gross revenue

# Compute pairwise correlation of columns to understand which columns may have interesting correlation
pixar_movies.corr()
# Out:
#                          Year Released    Length  RT Score  IMDB Score  \
# Year Released                 1.000000  0.534099 -0.385842   -0.076138
# Length                        0.534099  1.000000 -0.492301   -0.406876
# RT Score                     -0.385842 -0.492301  1.000000    0.876587
# IMDB Score                   -0.076138 -0.406876  0.876587    1.000000
# Metacritic Score             -0.258043 -0.288763  0.867997    0.891237
# Opening Weekend               0.740376  0.471698 -0.423794   -0.096896
# Worldwide Gross               0.503504  0.312400  0.167612    0.347247
# Domestic Gross                0.417111  0.123327  0.349368    0.548467
# Adjusted Domestic Gross      -0.373099 -0.310743  0.654057    0.619059
# International Gross           0.503543  0.379133  0.064001    0.218876
# Domestic %                   -0.438875 -0.500744  0.300440    0.240026
# International %               0.438724  0.500658 -0.300373   -0.240066
# Production Budget             0.892410  0.307082 -0.331351   -0.033545
# Oscars Nominated             -0.014485 -0.069799  0.632767    0.817596
# Oscars Won                    0.296232  0.125731  0.438174    0.575408
#
#                          Metacritic Score  Opening Weekend  Worldwide Gross  \
# Year Released                   -0.258043         0.740376         0.503504
# Length                          -0.288763         0.471698         0.312400
# RT Score                         0.867997        -0.423794         0.167612
# IMDB Score                       0.891237        -0.096896         0.347247
# Metacritic Score                 1.000000        -0.273258         0.220493
# Opening Weekend                 -0.273258         1.000000         0.688564
# Worldwide Gross                  0.220493         0.688564         1.000000
# Domestic Gross                   0.341773         0.624218         0.883506
# Adjusted Domestic Gross          0.532589         0.026921         0.460129
# International Gross              0.142197         0.662183         0.973036
# Domestic %                       0.157633        -0.421982        -0.543928
# International %                 -0.157579         0.421986         0.543915
# Production Budget               -0.213031         0.757867         0.551215
# Oscars Nominated                 0.838883        -0.056367         0.384349
# Oscars Won                       0.503676         0.316225         0.621834
#
#                          Domestic Gross  Adjusted Domestic Gross  \
# Year Released                  0.417111                -0.373099
# Length                         0.123327                -0.310743
# RT Score                       0.349368                 0.654057
# IMDB Score                     0.548467                 0.619059
# Metacritic Score               0.341773                 0.532589
# Opening Weekend                0.624218                 0.026921
# Worldwide Gross                0.883506                 0.460129
# Domestic Gross                 1.000000                 0.672332
# Adjusted Domestic Gross        0.672332                 1.000000
# International Gross            0.751641                 0.316879
# Domestic %                    -0.099319                 0.299128
# International %                0.099302                -0.298995
# Production Budget              0.385702                -0.347640
# Oscars Nominated               0.402677                 0.325413
# Oscars Won                     0.625018                 0.311573
#
#                          International Gross  Domestic %  International %  \
# Year Released                       0.503543   -0.438875         0.438724
# Length                              0.379133   -0.500744         0.500658
# RT Score                            0.064001    0.300440        -0.300373
# IMDB Score                          0.218876    0.240026        -0.240066
# Metacritic Score                    0.142197    0.157633        -0.157579
# Opening Weekend                     0.662183   -0.421982         0.421986
# Worldwide Gross                     0.973036   -0.543928         0.543915
# Domestic Gross                      0.751641   -0.099319         0.099302
# Adjusted Domestic Gross             0.316879    0.299128        -0.298995
# International Gross                 1.000000   -0.716986         0.716976
# Domestic %                         -0.716986    1.000000        -1.000000
# International %                     0.716976   -1.000000         1.000000
# Production Budget                   0.586223   -0.581244         0.581228
# Oscars Nominated                    0.352585   -0.142666         0.142492
# Oscars Won                          0.582735   -0.333284         0.333149
#
#                          Production Budget  Oscars Nominated  Oscars Won
# Year Released                     0.892410         -0.014485    0.296232
# Length                            0.307082         -0.069799    0.125731
# RT Score                         -0.331351          0.632767    0.438174
# IMDB Score                       -0.033545          0.817596    0.575408
# Metacritic Score                 -0.213031          0.838883    0.503676
# Opening Weekend                   0.757867         -0.056367    0.316225
# Worldwide Gross                   0.551215          0.384349    0.621834
# Domestic Gross                    0.385702          0.402677    0.625018
# Adjusted Domestic Gross          -0.347640          0.325413    0.311573
# International Gross               0.586223          0.352585    0.582735
# Domestic %                       -0.581244         -0.142666   -0.333284
# International %                   0.581228          0.142492    0.333149
# Production Budget                 1.000000          0.078973    0.352405
# Oscars Nominated                  0.078973          1.000000    0.734945
# Oscars Won                        0.352405          0.734945    1.000000

# %% [markdown]
# Domesitic Gross obviously has a strong positive correlation with Adusted Domestic Gross.  It makes sense that all of the critic reviews have a strong positive correlation with money made.  What isn't obvious aprior is which review score will correlate most strongly with box office success.  For example, it looks like RT has a really strong correlation, ubt Metacritic less so.

# %%
pixar_movies.plot(x='RT Score', y='Adjusted Domestic Gross', kind='scatter')
# Out:
# <img src="data:image/png;base64,...">

# %%
adjusted_gross = pixar_movies.copy()
adjusted_gross.set_index('Adjusted Domestic Gross', inplace=True)
adjusted_gross.head()
# Out:
#                          Year Released  Length  RT Score  IMDB Score  \
# Adjusted Domestic Gross
# 356.21                            1995      81       100        83.0
# 277.18                            1998      96        92        72.0
# 388.43                            1999      92       100        79.0
# 366.12                            2001      90        96        81.0
# 457.46                            2003     104        99        82.0
#
#                          Metacritic Score  Opening Weekend  Worldwide Gross  \
# Adjusted Domestic Gross
# 356.21                                 92            29.14            362.0
# 277.18                                 77            33.26            363.4
# 388.43                                 88            57.39            485.0
# 366.12                                 78            62.58            528.8
# 457.46                                 90            70.25            895.6
#
#                          Domestic Gross  International Gross  Domestic %  \
# Adjusted Domestic Gross
# 356.21                            191.8                170.2       52.98
# 277.18                            162.8                200.6       44.80
# 388.43                            245.9                239.2       50.70
# 366.12                            255.9                272.9       48.39
# 457.46                            339.7                555.9       37.93
#
#                          International %  Production Budget  Oscars Nominated  \
# Adjusted Domestic Gross
# 356.21                             47.02                 30               3.0
# 277.18                             55.20                 45               1.0
# 388.43                             49.32                 90               1.0
# 366.12                             51.61                115               3.0
# 457.46                             62.07                 94               4.0
#
#                          Oscars Won
# Adjusted Domestic Gross
# 356.21                          0.0
# 277.18                          0.0
# 388.43                          0.0
# 366.12                          1.0
# 457.46                          1.0
